# %% [markdown]
# <a href="https://colab.research.google.com/github/ChiriKamau/limaAI/blob/main/notebooks/Quantize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Start

# %%
from google.colab import drive
drive.mount('/content/drive')

# Install the YOLOv8 library
# !pip install ultralytics
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.3.248)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
import shutil
import os
from ultralytics import YOLO

# --- CONFIGURATION ---
# The folder where your .pt model lives currently
drive_models_dir = '/content/drive/MyDrive/Tomato_dataset/models'
model_filename = 'yolov8m_fruits.pt'

# The NEW folder where we want to save the result
drive_quant_dir = os.path.join(drive_models_dir, 'quantized')

# --- EXECUTION ---

# 1. Create the new "quantized" folder in Drive if it doesn't exist
os.makedirs(drive_quant_dir, exist_ok=True)
print(f"📂 Target folder confirmed: {drive_quant_dir}")

# 2. Copy the model FROM Drive TO Colab local storage (Safe zone)
drive_model_path = os.path.join(drive_models_dir, model_filename)
local_model_name = model_filename

print(f"🔄 Copying model to local workspace...")
shutil.copy(drive_model_path, local_model_name)

# 3. Load and Export locally
print("⏳ Starting export (this happens locally)...")
model = YOLO(local_model_name)
model.export(format='tflite', int8=True)

# 4. Move the result BACK to the new "quantized" folder in Drive
# Ultralytics creates a folder named like 'yolov8m_fruits_saved_model'
local_result_folder = model_filename.replace('.pt', '_saved_model')
final_destination = os.path.join(drive_quant_dir, local_result_folder)

print(f"💾 Moving results to: {final_destination}")

# Clean up old version if it exists in the destination to avoid errors
if os.path.exists(final_destination):
    shutil.rmtree(final_destination)

# Move the folder
if os.path.exists(local_result_folder):
    shutil.copytree(local_result_folder, final_destination)
    print("✅ Success! Check your 'quantized' folder in Google Drive.")
else:
    print("❌ Error: The local export folder was not found.")
# Out:
# 📂 Target folder confirmed: /content/drive/MyDrive/Tomato_dataset/models/quantized
# 🔄 Copying model to local workspace...
# ⏳ Starting export (this happens locally)...
# Ultralytics 8.3.248 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# WARNING ⚠️ INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
#
# PyTorch: starting from 'yolov8m_fruits.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 6, 2100) (49.4 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
# TensorFlow SavedModel: collecting INT8 calibration images from 'data=coco8.yaml'
# Fast image access ✅ (ping: 0.0±0.0 ms, read: 519.3±83.7 MB/s, size: 54.0 KB)
# Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 2.8Kit/s 0.0s
# WARNING ⚠️ TensorFlow SavedModel: >300 images recommended for INT8 calibration, found 4 images.
#
# ONNX: starting export with onnx 1.20.0 opset 22...
# ONNX: slimming with onnxslim 0.1.82...
# ONNX: export success ✅ 3.7s, saved as 'yolov8m_fruits.onnx' (98.7 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.8...
# Saved artifact at 'yolov8m_fruits_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 320, 320, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 6, 2100), dtype=tf.float32, name=None)
# Captures:
#   133077816752464: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133077816751504: TensorSpec(shape=(3, 3, 3, 48), dtype=tf.float32, name=None)
#   133077816750736: TensorSpec(shape=(48,), dtype=tf.float32, name=None)
#   133077816751696: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133077816751312: TensorSpec(shape=(3, 3, 48, 96), dtype=tf.float32, name=None)
#   133077816750544: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077816753040: TensorSpec(shape=(1, 1, 96, 96), dtype=tf.float32, name=None)
#   133077816750928: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077813549328: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077813551440: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077816751888: TensorSpec(shape=(3, 3, 48, 48), dtype=tf.float32, name=None)
#   133077816752848: TensorSpec(shape=(48,), dtype=tf.float32, name=None)
#   133077816752080: TensorSpec(shape=(3, 3, 48, 48), dtype=tf.float32, name=None)
#   133077816753232: TensorSpec(shape=(48,), dtype=tf.float32, name=None)
#   133077886452368: TensorSpec(shape=(3, 3, 48, 48), dtype=tf.float32, name=None)
#   133077886453136: TensorSpec(shape=(48,), dtype=tf.float32, name=None)
#   133077886452944: TensorSpec(shape=(3, 3, 48, 48), dtype=tf.float32, name=None)
#   133077886453520: TensorSpec(shape=(48,), dtype=tf.float32, name=None)
#   133077813551056: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077813549136: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886453904: TensorSpec(shape=(1, 1, 192, 96), dtype=tf.float32, name=None)
#   133077886453328: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077886454096: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133077886452560: TensorSpec(shape=(3, 3, 96, 192), dtype=tf.float32, name=None)
#   133077886453712: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077886454480: TensorSpec(shape=(1, 1, 192, 192), dtype=tf.float32, name=None)
#   133077886454672: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077886455248: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886455056: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886457168: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077886457360: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077886454864: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077886454288: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077886456592: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077886457552: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077886456208: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077886457936: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077886456784: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077886458320: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077886457744: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077886458512: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077886458704: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077886459088: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077886458128: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077886459280: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077886455440: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886455632: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886459856: TensorSpec(shape=(1, 1, 576, 192), dtype=tf.float32, name=None)
#   133077886458896: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077886460048: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133077886459472: TensorSpec(shape=(3, 3, 192, 384), dtype=tf.float32, name=None)
#   133077886459664: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133077886460432: TensorSpec(shape=(1, 1, 384, 384), dtype=tf.float32, name=None)
#   133077886460624: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133077886461200: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886461008: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886463120: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077886463312: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077886460816: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077886460240: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077886462544: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077886463504: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077886462160: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077886463888: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077886462736: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077886464272: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077886463696: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077886464464: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077886464656: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077886465040: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077886464080: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077886465232: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077886461392: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886461584: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886465808: TensorSpec(shape=(1, 1, 1152, 384), dtype=tf.float32, name=None)
#   133077886464848: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133077886466000: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133077886465424: TensorSpec(shape=(3, 3, 384, 576), dtype=tf.float32, name=None)
#   133077886465616: TensorSpec(shape=(576,), dtype=tf.float32, name=None)
#   133077886466384: TensorSpec(shape=(1, 1, 576, 576), dtype=tf.float32, name=None)
#   133077886466576: TensorSpec(shape=(576,), dtype=tf.float32, name=None)
#   133077886466960: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886467920: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886467152: TensorSpec(shape=(3, 3, 288, 288), dtype=tf.float32, name=None)
#   133077886467728: TensorSpec(shape=(288,), dtype=tf.float32, name=None)
#   133077886466768: TensorSpec(shape=(3, 3, 288, 288), dtype=tf.float32, name=None)
#   133077886466192: TensorSpec(shape=(288,), dtype=tf.float32, name=None)
#   133077815722640: TensorSpec(shape=(3, 3, 288, 288), dtype=tf.float32, name=None)
#   133077815723408: TensorSpec(shape=(288,), dtype=tf.float32, name=None)
#   133077815723216: TensorSpec(shape=(3, 3, 288, 288), dtype=tf.float32, name=None)
#   133077815723792: TensorSpec(shape=(288,), dtype=tf.float32, name=None)
#   133077886467344: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077886467536: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815724176: TensorSpec(shape=(1, 1, 1152, 576), dtype=tf.float32, name=None)
#   133077815723600: TensorSpec(shape=(576,), dtype=tf.float32, name=None)
#   133077815722832: TensorSpec(shape=(1, 1, 576, 288), dtype=tf.float32, name=None)
#   133077815724368: TensorSpec(shape=(288,), dtype=tf.float32, name=None)
#   133077815724560: TensorSpec(shape=(1, 1, 1152, 576), dtype=tf.float32, name=None)
#   133077815724944: TensorSpec(shape=(576,), dtype=tf.float32, name=None)
#   133077815725328: TensorSpec(shape=(1, 1, 960, 384), dtype=tf.float32, name=None)
#   133077815724752: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133077815725712: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815725520: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815727632: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077815727824: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815725136: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077815723984: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815727056: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077815728208: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815728016: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077815728400: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815725904: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815726096: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815728592: TensorSpec(shape=(1, 1, 768, 384), dtype=tf.float32, name=None)
#   133077815728784: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133077815729168: TensorSpec(shape=(1, 1, 576, 192), dtype=tf.float32, name=None)
#   133077815727248: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815729552: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815729360: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815731472: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077815731664: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077815728976: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077815726672: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077815730896: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077815732048: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077815731856: TensorSpec(shape=(3, 3, 96, 96), dtype=tf.float32, name=None)
#   133077815732240: TensorSpec(shape=(96,), dtype=tf.float32, name=None)
#   133077815729744: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815729936: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815732432: TensorSpec(shape=(1, 1, 384, 192), dtype=tf.float32, name=None)
#   133077815732624: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815732816: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133077815731088: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077815730512: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815734928: TensorSpec(shape=(1, 1, 576, 384), dtype=tf.float32, name=None)
#   133077815734352: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133077815736080: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815735888: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815736272: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077815737232: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815737808: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077815738000: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815735504: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077815738192: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815737616: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077814231696: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815736464: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077815736656: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077814232272: TensorSpec(shape=(1, 1, 768, 384), dtype=tf.float32, name=None)
#   133077814231888: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133077814231504: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133077814231312: TensorSpec(shape=(3, 3, 384, 384), dtype=tf.float32, name=None)
#   133077814232464: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133077814234384: TensorSpec(shape=(1, 1, 960, 576), dtype=tf.float32, name=None)
#   133077814233808: TensorSpec(shape=(576,), dtype=tf.float32, name=None)
#   133077814235536: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077814235344: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077814235728: TensorSpec(shape=(3, 3, 288, 288), dtype=tf.float32, name=None)
#   133077814239184: TensorSpec(shape=(288,), dtype=tf.float32, name=None)
#   133077814236688: TensorSpec(shape=(3, 3, 288, 288), dtype=tf.float32, name=None)
#   133077814237648: TensorSpec(shape=(288,), dtype=tf.float32, name=None)
#   133077814238992: TensorSpec(shape=(3, 3, 288, 288), dtype=tf.float32, name=None)
#   133077814237072: TensorSpec(shape=(288,), dtype=tf.float32, name=None)
#   133077814237264: TensorSpec(shape=(3, 3, 288, 288), dtype=tf.float32, name=None)
#   133077814238224: TensorSpec(shape=(288,), dtype=tf.float32, name=None)
#   133077814235920: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077814236112: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133077814238608: TensorSpec(shape=(1, 1, 1152, 576), dtype=tf.float32, name=None)
#   133077814238032: TensorSpec(shape=(576,), dtype=tf.float32, name=None)
#   133077814239376: TensorSpec(shape=(3, 3, 576, 192), dtype=tf.float32, name=None)
#   133077814234960: TensorSpec(shape=(3, 3, 576, 64), dtype=tf.float32, name=None)
#   133077814233232: TensorSpec(shape=(3, 3, 384, 192), dtype=tf.float32, name=None)
#   133077814232848: TensorSpec(shape=(3, 3, 384, 64), dtype=tf.float32, name=None)
#   133077815733776: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077815733392: TensorSpec(shape=(3, 3, 192, 64), dtype=tf.float32, name=None)
#   133077814238800: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077814238416: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133077814232080: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077814232656: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133077815733008: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815733200: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133077814240144: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077814239568: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133077814234000: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077814233040: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133077815734544: TensorSpec(shape=(3, 3, 192, 192), dtype=tf.float32, name=None)
#   133077815733584: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133077814239760: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077814239952: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133077814233616: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077814233424: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133077815734160: TensorSpec(shape=(192,), dtype=tf.float32, name=None)
#   133077815733968: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133077814240912: TensorSpec(shape=(1, 1, 192, 2), dtype=tf.float32, name=None)
#   133077814240336: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133077814235152: TensorSpec(shape=(1, 1, 192, 2), dtype=tf.float32, name=None)
#   133077814234768: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133077815735696: TensorSpec(shape=(1, 1, 192, 2), dtype=tf.float32, name=None)
#   133077815735312: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133077814240720: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133077814240528: TensorSpec(shape=(2,), dtype=tf.float32, name=None)
#   133077814234192: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133077814234576: TensorSpec(shape=(2,), dtype=tf.float32, name=None)
#   133077815734736: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133077815735120: TensorSpec(shape=(2,), dtype=tf.float32, name=None)
#   133077814242064: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   133077814242832: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133077814243024: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133077814242448: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133077814237840: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133077814243984: TensorSpec(shape=(1, 2, 2100), dtype=tf.float32, name=None)
#   133077814243408: TensorSpec(shape=(1, 2, 2100), dtype=tf.float32, name=None)
#
#
# TensorFlow SavedModel: export success ✅ 115.7s, saved as 'yolov8m_fruits_saved_model' (322.3 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as 'yolov8m_fruits_saved_model/yolov8m_fruits_int8.tflite' (25.0 MB)
#
# Export complete (117.0s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolov8m_fruits_saved_model/yolov8m_fruits_int8.tflite imgsz=320 int8
# Validate:        yolo val task=detect model=yolov8m_fruits_saved_model/yolov8m_fruits_int8.tflite imgsz=320 data=/content/data.yaml int8
# Visualize:       https://netron.app
# 💾 Moving results to: /content/drive/MyDrive/Tomato_dataset/models/quantized/yolov8m_fruits_saved_model
# ✅ Success! Check your 'quantized' folder in Google Drive.
